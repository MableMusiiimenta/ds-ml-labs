# %% [markdown]
# ## **Assigning** **Variables**

# %%
firstName = "Natalie"
print(firstName)
# Out:
# Natalie

# %%
x = 2
y = 7
print(x+y)
# Out:
# 9

# %% [markdown]
# ## **Data** **Types**

# %%
x = 2
y = 3.14
z = 4 + 5j
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(z))
# Out:
# <class 'complex'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
myList = [1,2,3,4,5]
myTuple = (1,2,3,4,5)
myRange =range(1,5)
print(type(myList))
# Out:
# <class 'list'>

# %%
print(type(myTuple))
# Out:
# <class 'tuple'>

# %%
print(type(myRange))
# Out:
# <class 'range'>

# %% [markdown]
# # **Mapping/Dictionary(Key:Value Pairs)**

# %%
pyrocyber={"Name":"Khosa", "Age": 23, "Sport":"Rugby", "Food":"Chapati"}
pyrocyber["Name"]
# Out:
# 'Khosa'

# %%
print(pyrocyber)
# Out:
# {'Name': 'Khosa', 'Age': 23, 'Sport': 'Rugby', 'Food': 'Chapati'}
