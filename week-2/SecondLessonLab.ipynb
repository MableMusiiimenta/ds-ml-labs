# %% [markdown]
# # **Python Functions**

# %%
letters = ["a","b", "c", "d", "e", "f", "g"]
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %% [markdown]
# ## **Append**

# %%
letters.append("h")

# %%
print(letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
letters.append(["a", "a"])
print(letters)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', ['a', 'a']]

# %% [markdown]
# ## **Extend**

# %%
letters.extend(["i","j"])

# %%
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', ['a', 'a'], 'i', 'j']

# %% [markdown]
# # **Insert**

# %%
letters.insert(0, 1)

# %%
letters
# Out:
# [1, 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', ['a', 'a'], 'i', 'j']

# %% [markdown]
# ## **Remove**

# %%
letters.remove("a")

# %%
print(letters)
# Out:
# [1, 'b', 'c', 'd', 'e', 'f', 'g', 'h', ['a', 'a'], 'i', 'j']

# %% [markdown]
# # **Pop**

# %%
pop_element = letters.pop(5)

# %%
print(pop_element)
# Out:
# f

# %%
print(letters)
# Out:
# [1, 'b', 'c', 'd', 'e', 'g', 'h', ['a', 'a'], 'i', 'j']

# %%
letters.pop(7)
# Out:
# ['a', 'a']

# %% [markdown]
# # **Index**

# %%
Index = letters.index("e")

# %%
print(Index)
# Out:
# 4

# %%
letters.pop(0)
# Out:
# 1

# %% [markdown]
# ## **Count**

# %%
Count = letters.count("a")
print(Count)
# Out:
# 0

# %%
MyCount = letters.count("h")
print(MyCount)
# Out:
# 1

# %% [markdown]
# # **Sort**

# %%
letters.sort()
letters
# Out:
# ['b', 'c', 'd', 'e', 'g', 'h', 'i', 'j']

# %%
letters.reverse()
letters
# Out:
# ['j', 'i', 'h', 'g', 'e', 'd', 'c', 'b']

# %%
myDictionary = dict([('name', ['Rebecca', 'Bobo', 'Nancy']), ('age', [20, 24, 28])])
print(myDictionary)
